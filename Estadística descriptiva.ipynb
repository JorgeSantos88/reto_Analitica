# %%
#Para poder analizar la información, debemos importar la librería pandas, que nos permite obtener información de 
#manera más sencilla
import pandas as pd
#En la variable data, guardamos la lectura del archivo con los datos
data = pd.read_csv("covid19_tweets.csv")
#Con head, obtenemos los primeros 5 objetos de la base de datos, y podemos visualizar las características e 
#información que cada columna contiene
data.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %%
#Utilizamos el comando tail para obtener los últimos 5 regsitros en la base de datos
data.tail()
# Out:
#                       user_name  user_location  \
# 74431             Laura Wolfrom  Lexington, KY
# 74432  Professor Tonya M. Evans  😷 #stayathome
# 74433        People's Daily app    北京, 中华人民共和国
# 74434                     M0ser            NaN
# 74435    Your Friend & Sabre ⚔️    Chicago, IL
#
#                                         user_description         user_created  \
# 74431            The only things I collect are memories.  2010-09-24 02:01:15
# 74432  Law Prof @DickinsonLaw & Entrepreneur | Crypto...  2013-05-14 20:15:24
# 74433  Our mission is to provide news and perspective...  2018-02-04 12:36:42
# 74434  Reagan conservative and attorney raised in the...  2014-02-18 03:46:28
# 74435  My spectral decomposition has a significant da...  2016-12-19 19:55:00
#
#        user_followers  user_friends  user_favourites  user_verified  \
# 74431              85           586             1902          False
# 74432            4289          1066            53569          False
# ...

# %%
#Para obtener los principales parámetros estadísticos, se utiliza el parámetro describe
#la tabla arroja únicamente los resultados de variables numéricas
data.describe()
# Out:
#        user_followers   user_friends  user_favourites
# count    7.443600e+04   74436.000000     7.443600e+04
# mean     1.059513e+05    2154.721170     1.529747e+04
# std      8.222900e+05    9365.587474     4.668971e+04
# min      0.000000e+00       0.000000     0.000000e+00
# 25%      1.660000e+02     153.000000     2.200000e+02
# 50%      9.600000e+02     552.000000     1.927000e+03
# 75%      5.148000e+03    1780.250000     1.014800e+04
# max      1.389284e+07  497363.000000     2.047197e+06

# %%
#Con el comando que incluye np.object, es posible obtener algunos estadísticos, principalmente frecuencias, 
#de algunas otras variables cualitativas
import numpy as np
data.describe(include=np.object)
# Out:
#                  user_name user_location  \
# count                74436         59218
# unique               44853         14622
# top     GlobalPandemic.NET         India
# freq                   312          1496
#
#                                          user_description  \
# count                                               70079
# unique                                              42690
# top     Breaking News & Critical Information to SURVIV...
# freq                                                  312
#
#                user_created                 date  \
# count                 74436                74436
# unique                45554                56546
# top     2010-07-13 21:58:05  2020-07-29 16:30:00
# freq                    312                   26
#
#                                                      text     hashtags  \
# count                                               74436        53002
# ...

# %%
#Hay columnas que no aparecen en ninguna de las dos variables anteriores (ambas variables son booleanas), 
#podemos usar el comando mode para encontrar el valor que más se repite
data['user_verified'].mode()
# Out:
# 0    False
# dtype: bool

# %%
data['is_retweet'].mode()
# Out:
# 0    False
# dtype: bool

# %%
#Con el comando corr, podemos encontrar si hay correlación entre las variables
#en este caso, los valores obtenidos son bajos, se concluye que no hay correlación significativa entre variables
data.corr()
# Out:
#                  user_followers  user_friends  user_favourites  user_verified  \
# user_followers         1.000000     -0.002722        -0.028724       0.322896
# user_friends          -0.002722      1.000000         0.207825       0.013099
# user_favourites       -0.028724      0.207825         1.000000      -0.060316
# user_verified          0.322896      0.013099        -0.060316       1.000000
# is_retweet                  NaN           NaN              NaN            NaN
#
#                  is_retweet
# user_followers          NaN
# user_friends            NaN
# user_favourites         NaN
# user_verified           NaN
# is_retweet              NaN

# %%
#Para tener una visualización gráfica de la distribución de algunas de las variables, se usa un boxplot
import matplotlib.pyplot as plt 
col1 = data['user_followers'] 
fig = plt.figure(figsize =(10, 7)) 
plt.boxplot(col1)
plt.show()

# %%
col1 = data['user_friends'] 
fig = plt.figure(figsize =(10, 7)) 
plt.boxplot(col1)
plt.show()

# %%
col1 = data['user_favourites'] 
fig = plt.figure(figsize =(10, 7)) 
plt.boxplot(col1)
plt.show()
